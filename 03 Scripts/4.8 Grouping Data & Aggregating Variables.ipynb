# %% [markdown]
# ## 4.8 Grouping Data & Aggregating Variables
#
# ### 1. Import libraries
# ### 2. Import Data Frame
# ### 3. Grouping Data with pandas
# ### 4. Aggregating Data with agg()
# ### 5. Aggregating Data with transform()
# ### 6. Deriving Columns with loc()
# ### 7. 4.8 Task: Grouping Data & Aggregating Variables
#     ### - Find the aggregated mean of the “order_number” column grouped by “department_id” for entire dataframe
#     ### - Check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).
#     ### - Create a spending flag for each user based on the average price across all their orders using the specific criteria.
#     ### - Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column with using the specific criteria.
#     ### - Missing value are 5 and to addresing these missing value .
# ### 8. Export Data Frame

# %% [markdown]
# ## 1. Import libraries

# %%
## import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Import Data Frame

# %%
## import data frame

path = r'/Users/eriseldabaci/Desktop/CareerFoundry/Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/eriseldabaci/Desktop/CareerFoundry/Python Fundamentals for Data Analysts/Instacart Basket Analysis'

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data ', 'orders_products_combined_new_variable.pkl'))

# %%
df = df_ords_prods_merged[:1000000]
df.shape
# Out:
# (1000000, 20)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                1.0
# 1                    15.0         False       196.0                1.0
# 2                    21.0         False       196.0                1.0
# 3                    29.0         False       196.0                1.0
# 4                    28.0         False       196.0                1.0
#
#    reordered _merge product_name  aisle_id  department_id  prices  \
# 0        0.0   both         Soda        77              7     9.0
# 1        1.0   both         Soda        77              7     9.0
# 2        1.0   both         Soda        77              7     9.0
# 3        1.0   both         Soda        77              7     9.0
# 4        1.0   both         Soda        77              7     9.0
#
#      price_range_loc     Busiest day  Busyness_Level    Busiest days  \
# 0  Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 1  Mid-range product  Regularly busy    Slowest days    Slowest days
# 2  Mid-range product  Regularly busy    Slowest days    Slowest days
# 3  Mid-range product      Least busy    Slowest days    Slowest days
# 4  Mid-range product      Least busy    Slowest days    Slowest days
#
#   busiest_period_of_day
# 0         Fewest orders
# 1         Fewest orders
# 2        Average orders
# 3         Fewest orders
# 4         Fewest orders

# %% [markdown]
# ## 3. Grouping Data with pandas

# %%
## grouping data

df.groupby('product_name')

# %% [markdown]
# ## 4. Aggregating Data with agg()

# %% [markdown]
# ### - Performing a Single Aggregation

# %%
## Performing a Single Aggregation

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
## The command above could be replaced with a command that uses the mean() function to achieve the same results:

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
## set the column name off with a dot, the same output as the function with brackets:

df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# ### - Performing Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## 5. Aggregating Data with transform()

# %%
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# 5                     19.0         False       196.0                1.0
# 6                     20.0         False       196.0                1.0
# 7                     14.0         False       196.0                2.0
# 8                      0.0         False       196.0                4.0
# 9                     30.0         False       196.0                1.0
# 10                     7.0         False       196.0                2.0
# 11                     8.0         False       196.0                6.0
# 12                     7.0         False       196.0                1.0
# 13                     7.0         False       196.0                1.0
# 14                    14.0         False       196.0                1.0
#
#     reordered  ... product_name aisle_id  department_id  prices  \
# 0         0.0  ...         Soda       77              7     9.0
# 1         1.0  ...         Soda       77              7     9.0
# 2         1.0  ...         Soda       77              7     9.0
# 3         1.0  ...         Soda       77              7     9.0
# 4         1.0  ...         Soda       77              7     9.0
# 5         1.0  ...         Soda       77              7     9.0
# 6         1.0  ...         Soda       77              7     9.0
# 7         1.0  ...         Soda       77              7     9.0
# 8         1.0  ...         Soda       77              7     9.0
# 9         1.0  ...         Soda       77              7     9.0
# 10        0.0  ...         Soda       77              7     9.0
# 11        1.0  ...         Soda       77              7     9.0
# 12        1.0  ...         Soda       77              7     9.0
# 13        1.0  ...         Soda       77              7     9.0
# 14        1.0  ...         Soda       77              7     9.0
#
#       price_range_loc     Busiest day  Busyness_Level    Busiest days  \
# 0   Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 1   Mid-range product  Regularly busy    Slowest days    Slowest days
# 2   Mid-range product  Regularly busy    Slowest days    Slowest days
# 3   Mid-range product      Least busy    Slowest days    Slowest days
# 4   Mid-range product      Least busy    Slowest days    Slowest days
# 5   Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 6   Mid-range product  Regularly busy    Busiest days    Busiest days
# 7   Mid-range product  Regularly busy    Busiest days    Busiest days
# 8   Mid-range product  Regularly busy    Busiest days    Busiest days
# 9   Mid-range product      Least busy    Slowest days    Slowest days
# 10  Mid-range product  Regularly busy    Busiest days    Busiest days
# 11  Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 12  Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 13  Mid-range product  Regularly busy    Busiest days    Busiest days
# 14  Mid-range product  Regularly busy    Busiest days    Busiest days
#
#    busiest_period_of_day max_order
# 0          Fewest orders        10
# 1          Fewest orders        10
# 2         Average orders        10
# 3          Fewest orders        10
# 4          Fewest orders        10
# 5          Fewest orders        10
# 6          Fewest orders        10
# 7         Average orders        10
# 8            Most orders        10
# 9          Fewest orders        10
# 10         Fewest orders        22
# 11           Most orders        22
# 12        Average orders        22
# 13         Fewest orders        22
# 14         Fewest orders        22
#
# [15 rows x 21 columns]

# %%
df_ords_prods_merged.head(100)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# ..       ...      ...           ...                ...                ...
# 95   3226575      360             1                  5                 12
# 96   1469869      377             3                  5                 17
# 97   1927023      387             2                  4                 10
# 98    858092      420             4                  1                 19
# 99    119314      420             5                  3                 19
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# ..                     ...           ...         ...                ...
# 95                     NaN          True       196.0                1.0
# 96                     3.0         False       196.0                9.0
# 97                    22.0         False       196.0                3.0
# 98                    30.0         False       196.0                2.0
# 99                    16.0         False       196.0                2.0
#
#     reordered  ... product_name aisle_id  department_id  prices  \
# 0         0.0  ...         Soda       77              7     9.0
# 1         1.0  ...         Soda       77              7     9.0
# 2         1.0  ...         Soda       77              7     9.0
# 3         1.0  ...         Soda       77              7     9.0
# 4         1.0  ...         Soda       77              7     9.0
# ..        ...  ...          ...      ...            ...     ...
# 95        0.0  ...         Soda       77              7     9.0
# 96        0.0  ...         Soda       77              7     9.0
# 97        0.0  ...         Soda       77              7     9.0
# 98        0.0  ...         Soda       77              7     9.0
# 99        1.0  ...         Soda       77              7     9.0
#
#       price_range_loc     Busiest day  Busyness_Level    Busiest days  \
# 0   Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 1   Mid-range product  Regularly busy    Slowest days    Slowest days
# 2   Mid-range product  Regularly busy    Slowest days    Slowest days
# 3   Mid-range product      Least busy    Slowest days    Slowest days
# 4   Mid-range product      Least busy    Slowest days    Slowest days
# ..                ...             ...             ...             ...
# 95  Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 96  Mid-range product  Regularly busy  Regularly busy  Regularly busy
# 97  Mid-range product      Least busy    Slowest days    Slowest days
# 98  Mid-range product  Regularly busy    Busiest days    Busiest days
# 99  Mid-range product  Regularly busy    Slowest days    Slowest days
#
#    busiest_period_of_day max_order
# 0          Fewest orders        10
# 1          Fewest orders        10
# 2         Average orders        10
# 3          Fewest orders        10
# 4          Fewest orders        10
# ..                   ...       ...
# 95        Average orders         3
# 96           Most orders         3
# 97         Fewest orders         8
# 98           Most orders        22
# 99           Most orders        22
#
# [100 rows x 21 columns]

# %% [markdown]
# ## 6. Deriving Columns with loc()

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
#
# NameError: name 'ords_prods_merge' is not defined

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# ## 7. 4.8 Task : Grouping & Aggregating Variables

# %% [markdown]
#  ### - Find the aggregated mean of the “order_number” column grouped by “department_id” for entire dataframe

# %%
 ### - Find the aggregated mean of the “order_number” column grouped by “department_id” for entire dataframe
    
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### The result of the entire data frame is different form the subset, the department_ID 21 has the max mean around 23, which is different form subset when there the max mean is around 19 and the department_id is 19 and of course this change what their best-selling departments is.

# %% [markdown]
# ### - Check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).

# %%
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices': ['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### - Create a spending flag for each user based on the average price across all their orders using the following criteria:
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
## Create a new column 'average_price' with aggregated mean() 'prices' by user_id

df_ords_prods_merged['average_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
## Check the output

df_ords_prods_merged.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# 5                     19.0         False       196.0                1.0
# 6                     20.0         False       196.0                1.0
# 7                     14.0         False       196.0                2.0
# 8                      0.0         False       196.0                4.0
# 9                     30.0         False       196.0                1.0
# 10                     7.0         False       196.0                2.0
# 11                     8.0         False       196.0                6.0
# 12                     7.0         False       196.0                1.0
# 13                     7.0         False       196.0                1.0
# 14                    14.0         False       196.0                1.0
# 15                     6.0         False       196.0                3.0
# 16                     8.0         False       196.0               15.0
# 17                     6.0         False       196.0                1.0
# 18                     6.0         False       196.0                2.0
# 19                     7.0         False       196.0               17.0
#
#     reordered  ... department_id prices    price_range_loc     Busiest day  \
# 0         0.0  ...             7    9.0  Mid-range product  Regularly busy
# 1         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 2         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 3         1.0  ...             7    9.0  Mid-range product      Least busy
# 4         1.0  ...             7    9.0  Mid-range product      Least busy
# 5         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 6         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 7         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 8         1.0  ...             7    9.0  Mid-range product  Regularly busy
# 9         1.0  ...             7    9.0  Mid-range product      Least busy
# 10        0.0  ...             7    9.0  Mid-range product  Regularly busy
# 11        1.0  ...             7    9.0  Mid-range product  Regularly busy
# 12        1.0  ...             7    9.0  Mid-range product  Regularly busy
# 13        1.0  ...             7    9.0  Mid-range product  Regularly busy
# 14        1.0  ...             7    9.0  Mid-range product  Regularly busy
# 15        0.0  ...             7    9.0  Mid-range product  Regularly busy
# 16        1.0  ...             7    9.0  Mid-range product  Regularly busy
# 17        1.0  ...             7    9.0  Mid-range product      Least busy
# 18        0.0  ...             7    9.0  Mid-range product  Regularly busy
# 19        0.0  ...             7    9.0  Mid-range product  Regularly busy
#
#     Busyness_Level    Busiest days busiest_period_of_day max_order  \
# 0   Regularly busy  Regularly busy         Fewest orders        10
# 1     Slowest days    Slowest days         Fewest orders        10
# 2     Slowest days    Slowest days        Average orders        10
# 3     Slowest days    Slowest days         Fewest orders        10
# 4     Slowest days    Slowest days         Fewest orders        10
# 5   Regularly busy  Regularly busy         Fewest orders        10
# 6     Busiest days    Busiest days         Fewest orders        10
# 7     Busiest days    Busiest days        Average orders        10
# 8     Busiest days    Busiest days           Most orders        10
# 9     Slowest days    Slowest days         Fewest orders        10
# 10    Busiest days    Busiest days         Fewest orders        22
# 11  Regularly busy  Regularly busy           Most orders        22
# 12  Regularly busy  Regularly busy        Average orders        22
# 13    Busiest days    Busiest days         Fewest orders        22
# 14    Busiest days    Busiest days         Fewest orders        22
# 15  Regularly busy  Regularly busy        Average orders         9
# 16  Regularly busy  Regularly busy        Average orders         9
# 17    Slowest days    Slowest days           Most orders         9
# 18    Slowest days    Slowest days         Fewest orders        33
# 19    Slowest days    Slowest days         Fewest orders        20
#
#         loyalty_flag average_price
# 0       New customer      6.367797
# 1       New customer      6.367797
# 2       New customer      6.367797
# 3       New customer      6.367797
# 4       New customer      6.367797
# 5       New customer      6.367797
# 6       New customer      6.367797
# 7       New customer      6.367797
# 8       New customer      6.367797
# 9       New customer      6.367797
# 10  Regular customer      3.980556
# 11  Regular customer      3.980556
# 12  Regular customer      3.980556
# 13  Regular customer      3.980556
# 14  Regular customer      3.980556
# 15      New customer      8.372059
# 16      New customer      8.372059
# 17      New customer      8.372059
# 18  Regular customer      7.012683
# 19  Regular customer      8.137793
#
# [20 rows x 23 columns]

# %%
# FLAG - Low spender (lowest average price value)

df_ords_prods_merged.loc[df_ords_prods_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# FLAG - High spender (higher average price value)

df_ords_prods_merged.loc[df_ords_prods_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# Check Output of spending_flag 

df_ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
## Check the columns of speding_flas

df_ords_prods_merged[['user_id', 'spending_flag', 'prices']].head(60)
# Out:
#     user_id spending_flag  prices
# 0         1   Low spender     9.0
# 1         1   Low spender     9.0
# 2         1   Low spender     9.0
# 3         1   Low spender     9.0
# 4         1   Low spender     9.0
# 5         1   Low spender     9.0
# 6         1   Low spender     9.0
# 7         1   Low spender     9.0
# 8         1   Low spender     9.0
# 9         1   Low spender     9.0
# 10       15   Low spender     9.0
# 11       15   Low spender     9.0
# 12       15   Low spender     9.0
# 13       15   Low spender     9.0
# 14       15   Low spender     9.0
# 15       19   Low spender     9.0
# 16       19   Low spender     9.0
# 17       19   Low spender     9.0
# 18       21   Low spender     9.0
# 19       31   Low spender     9.0
# 20       31   Low spender     9.0
# 21       43   Low spender     9.0
# 22       43   Low spender     9.0
# 23       52   Low spender     9.0
# 24       52   Low spender     9.0
# 25       52   Low spender     9.0
# 26       52   Low spender     9.0
# 27       52   Low spender     9.0
# 28       52   Low spender     9.0
# 29       52   Low spender     9.0
# 30       52   Low spender     9.0
# 31       52   Low spender     9.0
# 32       52   Low spender     9.0
# 33       52   Low spender     9.0
# 34       52   Low spender     9.0
# 35       52   Low spender     9.0
# 36       52   Low spender     9.0
# 37       67   Low spender     9.0
# 38       67   Low spender     9.0
# 39       67   Low spender     9.0
# 40       67   Low spender     9.0
# 41       67   Low spender     9.0
# 42       67   Low spender     9.0
# 43       67   Low spender     9.0
# 44       67   Low spender     9.0
# 45       67   Low spender     9.0
# 46       67   Low spender     9.0
# 47       67   Low spender     9.0
# 48       67   Low spender     9.0
# 49       67   Low spender     9.0
# 50       67   Low spender     9.0
# 51       67   Low spender     9.0
# 52       67   Low spender     9.0
# 53       67   Low spender     9.0
# 54       67   Low spender     9.0
# 55       67   Low spender     9.0
# 56       81   Low spender     9.0
# 57       81   Low spender     9.0
# 58       82   Low spender     9.0
# 59       82   Low spender     9.0

# %% [markdown]
# ### - Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column with using the specific criteria. The criteria for the flag should be as follows:
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
## # MEDIAN FLAG (for days_since_prior_order)- Create 'ordering_behavior' column with aggregated median days_since_prior_order by user_id

df_ords_prods_merged['ordering_behavior'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
## check the data frame 

df_ords_prods_merged.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
#
#     days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                      NaN          True       196.0                1.0
# 1                     15.0         False       196.0                1.0
# 2                     21.0         False       196.0                1.0
# 3                     29.0         False       196.0                1.0
# 4                     28.0         False       196.0                1.0
# 5                     19.0         False       196.0                1.0
# 6                     20.0         False       196.0                1.0
# 7                     14.0         False       196.0                2.0
# 8                      0.0         False       196.0                4.0
# 9                     30.0         False       196.0                1.0
# 10                     7.0         False       196.0                2.0
# 11                     8.0         False       196.0                6.0
# 12                     7.0         False       196.0                1.0
# 13                     7.0         False       196.0                1.0
# 14                    14.0         False       196.0                1.0
# 15                     6.0         False       196.0                3.0
# 16                     8.0         False       196.0               15.0
# 17                     6.0         False       196.0                1.0
# 18                     6.0         False       196.0                2.0
# 19                     7.0         False       196.0               17.0
#
#     reordered  ...    price_range_loc     Busiest day  Busyness_Level  \
# 0         0.0  ...  Mid-range product  Regularly busy  Regularly busy
# 1         1.0  ...  Mid-range product  Regularly busy    Slowest days
# 2         1.0  ...  Mid-range product  Regularly busy    Slowest days
# 3         1.0  ...  Mid-range product      Least busy    Slowest days
# 4         1.0  ...  Mid-range product      Least busy    Slowest days
# 5         1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 6         1.0  ...  Mid-range product  Regularly busy    Busiest days
# 7         1.0  ...  Mid-range product  Regularly busy    Busiest days
# 8         1.0  ...  Mid-range product  Regularly busy    Busiest days
# 9         1.0  ...  Mid-range product      Least busy    Slowest days
# 10        0.0  ...  Mid-range product  Regularly busy    Busiest days
# 11        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 12        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 13        1.0  ...  Mid-range product  Regularly busy    Busiest days
# 14        1.0  ...  Mid-range product  Regularly busy    Busiest days
# 15        0.0  ...  Mid-range product  Regularly busy  Regularly busy
# 16        1.0  ...  Mid-range product  Regularly busy  Regularly busy
# 17        1.0  ...  Mid-range product      Least busy    Slowest days
# 18        0.0  ...  Mid-range product  Regularly busy    Slowest days
# 19        0.0  ...  Mid-range product  Regularly busy    Slowest days
#
#       Busiest days  busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy          Fewest orders        10      New customer
# 1     Slowest days          Fewest orders        10      New customer
# 2     Slowest days         Average orders        10      New customer
# 3     Slowest days          Fewest orders        10      New customer
# 4     Slowest days          Fewest orders        10      New customer
# 5   Regularly busy          Fewest orders        10      New customer
# 6     Busiest days          Fewest orders        10      New customer
# 7     Busiest days         Average orders        10      New customer
# 8     Busiest days            Most orders        10      New customer
# 9     Slowest days          Fewest orders        10      New customer
# 10    Busiest days          Fewest orders        22  Regular customer
# 11  Regularly busy            Most orders        22  Regular customer
# 12  Regularly busy         Average orders        22  Regular customer
# 13    Busiest days          Fewest orders        22  Regular customer
# 14    Busiest days          Fewest orders        22  Regular customer
# 15  Regularly busy         Average orders         9      New customer
# 16  Regularly busy         Average orders         9      New customer
# 17    Slowest days            Most orders         9      New customer
# 18    Slowest days          Fewest orders        33  Regular customer
# 19    Slowest days          Fewest orders        20  Regular customer
#
#    average_price spending_flag ordering_behavior
# 0       6.367797   Low spender              20.5
# 1       6.367797   Low spender              20.5
# 2       6.367797   Low spender              20.5
# 3       6.367797   Low spender              20.5
# 4       6.367797   Low spender              20.5
# 5       6.367797   Low spender              20.5
# 6       6.367797   Low spender              20.5
# 7       6.367797   Low spender              20.5
# 8       6.367797   Low spender              20.5
# 9       6.367797   Low spender              20.5
# 10      3.980556   Low spender              10.0
# 11      3.980556   Low spender              10.0
# 12      3.980556   Low spender              10.0
# 13      3.980556   Low spender              10.0
# 14      3.980556   Low spender              10.0
# 15      8.372059   Low spender               6.0
# 16      8.372059   Low spender               6.0
# 17      8.372059   Low spender               6.0
# 18      7.012683   Low spender               7.5
# 19      8.137793   Low spender               6.0
#
# [20 rows x 25 columns]

# %%
## Flag - 'Non-frequent customer' based on 'ordering_behavior'

df_ords_prods_merged.loc[df_ords_prods_merged['ordering_behavior'] > 20, 'order_frequency'] = 'Non-frequent customer'

# %%
## Flag - 'Regular customer' based on 'ordering_behavior'

df_ords_prods_merged.loc[(df_ords_prods_merged['ordering_behavior'] > 10) & (df_ords_prods_merged['ordering_behavior'] <= 20), 'order_frequency'] = 'Regular customer'

# %%
## Flag - 'Frequent customer' based on 'ordering_behavior'

df_ords_prods_merged.loc[df_ords_prods_merged['ordering_behavior'] <= 10, 'order_frequency'] = 'Frequent customer'

# %%
## Check out the output

df_ords_prods_merged['order_frequency'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency, dtype: int64

# %% [markdown]
# ### - Missing value are 5 and to addresing these missing value

# %%
# Missing Value Subset

df_ords_prods_merged_nan = df_ords_prods_merged.loc[df_ords_prods_merged['order_frequency'].isnull()==True]

df_ords_prods_merged_nan.shape
# Out:
# (5, 26)

# %%
# Check DataFrame Dimension (before removing missing values in order frequency column)

df_ords_prods_merged.shape
# Out:
# (32404859, 26)

# %%
# Create new products dataframe without missing values and Check DataFrame dimension

df_ords_prods_merged_clean = df_ords_prods_merged[df_ords_prods_merged['order_frequency'].isnull()==False]

df_ords_prods_merged_clean.shape
# Out:
# (32404854, 26)

# %%
# Check Output of MEDIAN FLAG

df_ords_prods_merged[['user_id', 'spending_flag', 'order_frequency', 'ordering_behavior']].head(20)
# Out:
#     user_id spending_flag        order_frequency  ordering_behavior
# 0         1   Low spender  Non-frequent customer               20.5
# 1         1   Low spender  Non-frequent customer               20.5
# 2         1   Low spender  Non-frequent customer               20.5
# 3         1   Low spender  Non-frequent customer               20.5
# 4         1   Low spender  Non-frequent customer               20.5
# 5         1   Low spender  Non-frequent customer               20.5
# 6         1   Low spender  Non-frequent customer               20.5
# 7         1   Low spender  Non-frequent customer               20.5
# 8         1   Low spender  Non-frequent customer               20.5
# 9         1   Low spender  Non-frequent customer               20.5
# 10       15   Low spender      Frequent customer               10.0
# 11       15   Low spender      Frequent customer               10.0
# 12       15   Low spender      Frequent customer               10.0
# 13       15   Low spender      Frequent customer               10.0
# 14       15   Low spender      Frequent customer               10.0
# 15       19   Low spender      Frequent customer                6.0
# 16       19   Low spender      Frequent customer                6.0
# 17       19   Low spender      Frequent customer                6.0
# 18       21   Low spender      Frequent customer                7.5
# 19       31   Low spender      Frequent customer                6.0

# %% [markdown]
# ### 8. Export Data Frame

# %%
# Export data to pkl

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data ', 'orders_products_combined_update2.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True       196.0                1.0
# 1                    15.0         False       196.0                1.0
# 2                    21.0         False       196.0                1.0
# 3                    29.0         False       196.0                1.0
# 4                    28.0         False       196.0                1.0
#
#    reordered  ...     Busiest day  Busyness_Level    Busiest days  \
# 0        0.0  ...  Regularly busy  Regularly busy  Regularly busy
# 1        1.0  ...  Regularly busy    Slowest days    Slowest days
# 2        1.0  ...  Regularly busy    Slowest days    Slowest days
# 3        1.0  ...      Least busy    Slowest days    Slowest days
# 4        1.0  ...      Least busy    Slowest days    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag average_price spending_flag  \
# 0          Fewest orders         10  New customer      6.367797   Low spender
# 1          Fewest orders         10  New customer      6.367797   Low spender
# 2         Average orders         10  New customer      6.367797   Low spender
# 3          Fewest orders         10  New customer      6.367797   Low spender
# 4          Fewest orders         10  New customer      6.367797   Low spender
#
#   ordering_behavior        order_frequency
# 0              20.5  Non-frequent customer
# 1              20.5  Non-frequent customer
# 2              20.5  Non-frequent customer
# 3              20.5  Non-frequent customer
# 4              20.5  Non-frequent customer
#
# [5 rows x 26 columns]
